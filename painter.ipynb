# %%
import matplotlib.pyplot as plt  
import os
import json
import time

os.system("python3 generator.py 23 poisson")

plt.figure(figsize = (20, 10))

#for day in range(20):
#    if day * 1440 >= 10000 and day * 1440 <= 20000:
#        plt.vlines(x = day * 1440, ymin = 28, ymax = 38, colors= 'purple', ls = '--', lw = 2)

plt.vlines(x = 250000, ymin = 0, ymax = 60, colors= 'purple', ls = '--', lw = 2)
plt.vlines(x = 500000, ymin = 0, ymax = 60, colors= 'purple', ls = '--', lw = 2)

timer = time.time()
policies = [['min-skew', 'no-migration', 'non-adaptive'],
            ['worst-fit', 'no-migration', 'non-adaptive'],
            ['first-fit', 'no-migration', 'non-adaptive'],
            ['first-fit-f-res', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'adaptive'],
            ['best-fit', 'migration-simple', 'non-adaptive'],
            ['min-add-time-bf', 'no-migration', 'non-adaptive'],
            ['min-add-time-bf', 'migration-simple', 'adaptive'],]
for policy in policies:
    os.system("python3 simulator.py {} {} {}".format(policy[0], policy[1], policy[2]))
    data = json.load(open("output.json"))
    X = []
    Y = []
    for elem in data:
        #if elem['time'] >= 10000 and elem['time'] <= 20000:
        X.append(elem['time'])
        Y.append(elem['current energy'])
    plt.title("Energy consumption over time", fontsize = 24)
    plt.plot(X, Y, label = policy)

# ideal result in terms of number of bins used, simply the ideal_bins_number = int(total_util) + 1
    
#os.system("python3 simulator.py {}".format(policy, 'non-adaptive'))
#data = json.load(open("output.json"))
#X = []
#Y = []
#for elem in data:
#    X.append(elem['time'])
#    Y.append(elem['ideal result'])
#
#plt.plot(X, Y, label = 'ideal result')
plt.legend(fontsize = 12)
print("Total time = {}".format(time.time() - timer))
# Out:
# Total time = 139.75232911109924

# %%
import matplotlib.pyplot as plt  
import os
import json
import time

os.system("python3 generator.py 23 poisson")

plt.figure(figsize = (20, 10))

#for day in range(20):
#    if day * 1440 >= 10000 and day * 1440 <= 20000:
#        plt.vlines(x = day * 1440, ymin = 28, ymax = 38, colors= 'purple', ls = '--', lw = 2)

plt.vlines(x = 300000, ymin = 0, ymax = 35, colors= 'purple', ls = '--', lw = 2)
plt.vlines(x = 600000, ymin = 0, ymax = 35, colors= 'purple', ls = '--', lw = 2)

timer = time.time()
policies = [['min-skew', 'no-migration', 'non-adaptive'],
            ['worst-fit', 'no-migration', 'non-adaptive'],
            ['first-fit', 'no-migration', 'non-adaptive'],
            ['first-fit-f-res', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'adaptive'],
            ['best-fit', 'migration-simple', 'non-adaptive'],
            ['min-add-time-bf', 'no-migration', 'non-adaptive'],
            ['min-add-time-bf', 'migration-simple', 'adaptive'],]
for policy in policies:
    os.system("python3 simulator.py {} {} {}".format(policy[0], policy[1], policy[2]))
    data = json.load(open("output.json"))
    X = []
    Y = []
    for elem in data:
        #if elem['time'] >= 10000 and elem['time'] <= 20000:
        X.append(elem['time'])
        Y.append(elem['current energy'])
    plt.title("Energy consumption over time", fontsize = 24)
    plt.plot(X, Y, label = policy)

# ideal result in terms of number of bins used, simply the ideal_bins_number = int(total_util) + 1
    
#os.system("python3 simulator.py {}".format(policy, 'non-adaptive'))
#data = json.load(open("output.json"))
#X = []
#Y = []
#for elem in data:
#    X.append(elem['time'])
#    Y.append(elem['ideal result'])
#
#plt.plot(X, Y, label = 'ideal result')
plt.legend(fontsize = 12)
print("Total time = {}".format(time.time() - timer))
# Out:
# Total time = 84.1200270652771

# %%
import matplotlib.pyplot as plt  
import os
import json
import time

os.system("python3 generator.py 23 poisson")

plt.figure(figsize = (20, 10))

#for day in range(20):
#    if day * 1440 >= 10000 and day * 1440 <= 20000:
#        plt.vlines(x = day * 1440, ymin = 28, ymax = 38, colors= 'purple', ls = '--', lw = 2)

plt.vlines(x = 200000, ymin = 0, ymax = 75, colors= 'purple', ls = '--', lw = 2)
plt.vlines(x = 330000, ymin = 0, ymax = 75, colors= 'purple', ls = '--', lw = 2)

timer = time.time()
policies = [['min-skew', 'no-migration', 'non-adaptive'],
            ['worst-fit', 'no-migration', 'non-adaptive'],
            ['first-fit', 'no-migration', 'non-adaptive'],
            ['first-fit-f-res', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'adaptive'],
            ['best-fit', 'migration-simple', 'non-adaptive'],
            ['min-add-time-bf', 'no-migration', 'non-adaptive'],
            ['min-add-time-bf', 'migration-simple', 'adaptive'],]
for policy in policies:
    os.system("python3 simulator.py {} {} {}".format(policy[0], policy[1], policy[2]))
    data = json.load(open("output.json"))
    X = []
    Y = []
    for elem in data:
        #if elem['time'] >= 10000 and elem['time'] <= 20000:
        X.append(elem['time'])
        Y.append(elem['current energy'])
    plt.title("Energy consumption over time", fontsize = 24)
    plt.plot(X, Y, label = policy)

# ideal result in terms of number of bins used, simply the ideal_bins_number = int(total_util) + 1
    
#os.system("python3 simulator.py {}".format(policy, 'non-adaptive'))
#data = json.load(open("output.json"))
#X = []
#Y = []
#for elem in data:
#    X.append(elem['time'])
#    Y.append(elem['ideal result'])
#
#plt.plot(X, Y, label = 'ideal result')
plt.legend(fontsize = 12)
print("Total time = {}".format(time.time() - timer))
# Out:
# Total time = 103.88355135917664

# %%
import matplotlib.pyplot as plt  
import os
import json
import time

os.system("python3 generator.py 23 poisson")

plt.figure(figsize = (20, 10))

#for day in range(20):
#    if day * 1440 >= 10000 and day * 1440 <= 20000:
#        plt.vlines(x = day * 1440, ymin = 28, ymax = 38, colors= 'purple', ls = '--', lw = 2)

plt.vlines(x = 200000, ymin = 0, ymax = 75, colors= 'purple', ls = '--', lw = 2)
plt.vlines(x = 400000, ymin = 0, ymax = 75, colors= 'purple', ls = '--', lw = 2)

timer = time.time()
policies = [['min-skew', 'no-migration', 'non-adaptive'],
            ['worst-fit', 'no-migration', 'non-adaptive'],
            ['first-fit', 'no-migration', 'non-adaptive'],
            ['first-fit-f-res', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'adaptive'],
            ['best-fit', 'migration-simple', 'non-adaptive'],
            ['min-add-time-bf', 'no-migration', 'non-adaptive'],
            ['min-add-time-bf', 'migration-simple', 'adaptive'],]
for policy in policies:
    os.system("python3 simulator.py {} {} {}".format(policy[0], policy[1], policy[2]))
    data = json.load(open("output.json"))
    X = []
    Y = []
    for elem in data:
        #if elem['time'] >= 10000 and elem['time'] <= 20000:
        X.append(elem['time'])
        Y.append(elem['current energy'])
    plt.title("Energy consumption over time", fontsize = 24)
    plt.plot(X, Y, label = policy)

# ideal result in terms of number of bins used, simply the ideal_bins_number = int(total_util) + 1
    
#os.system("python3 simulator.py {}".format(policy, 'non-adaptive'))
#data = json.load(open("output.json"))
#X = []
#Y = []
#for elem in data:
#    X.append(elem['time'])
#    Y.append(elem['ideal result'])
#
#plt.plot(X, Y, label = 'ideal result')
plt.legend(fontsize = 12)
print("Total time = {}".format(time.time() - timer))
# Out:
# Total time = 99.8801920413971

# %%
import matplotlib.pyplot as plt  
import os
import json
import time

os.system("python3 generator.py 23 poisson")

plt.figure(figsize = (20, 10))

#for day in range(20):
#    if day * 1440 >= 10000 and day * 1440 <= 20000:
#        plt.vlines(x = day * 1440, ymin = 28, ymax = 38, colors= 'purple', ls = '--', lw = 2)

plt.vlines(x = 200000, ymin = 0, ymax = 75, colors= 'purple', ls = '--', lw = 2)
plt.vlines(x = 400000, ymin = 0, ymax = 75, colors= 'purple', ls = '--', lw = 2)

timer = time.time()
policies = [['min-skew', 'no-migration', 'non-adaptive'],
            ['worst-fit', 'no-migration', 'non-adaptive'],
            ['first-fit', 'no-migration', 'non-adaptive'],
            ['first-fit-f-res', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'adaptive'],
            ['best-fit', 'migration-simple', 'non-adaptive'],
            ['min-add-time-bf', 'no-migration', 'non-adaptive'],
            ['min-add-time-bf', 'migration-simple', 'adaptive'],]
for policy in policies:
    os.system("python3 simulator.py {} {} {}".format(policy[0], policy[1], policy[2]))
    data = json.load(open("output.json"))
    X = []
    Y = []
    for elem in data:
        #if elem['time'] >= 10000 and elem['time'] <= 20000:
        X.append(elem['time'])
        Y.append(elem['current energy'])
    plt.title("Energy consumption over time", fontsize = 24)
    plt.plot(X, Y, label = policy)

# ideal result in terms of number of bins used, simply the ideal_bins_number = int(total_util) + 1
    
#os.system("python3 simulator.py {}".format(policy, 'non-adaptive'))
#data = json.load(open("output.json"))
#X = []
#Y = []
#for elem in data:
#    X.append(elem['time'])
#    Y.append(elem['ideal result'])
#
#plt.plot(X, Y, label = 'ideal result')
plt.legend(fontsize = 12)
print("Total time = {}".format(time.time() - timer))
# Out:
# Total time = 96.64099597930908

# %%
import matplotlib.pyplot as plt  
import os
import json
import time

os.system("python3 generator.py 23 poisson")

plt.figure(figsize = (20, 10))

#for day in range(20):
#    if day * 1440 >= 10000 and day * 1440 <= 20000:
#        plt.vlines(x = day * 1440, ymin = 28, ymax = 38, colors= 'purple', ls = '--', lw = 2)

timer = time.time()
policies = [['min-skew', 'no-migration', 'non-adaptive'],
            ['worst-fit', 'no-migration', 'non-adaptive'],
            ['first-fit', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'adaptive'],
            ['best-fit', 'no-migration', 'non-adaptive'],
            ['best-fit', 'migration-simple', 'non-adaptive'],
            ['min-add-time-bf', 'no-migration', 'non-adaptive'],
            ['min-add-time-bf', 'migration-simple', 'adaptive'],]
for policy in policies:
    os.system("python3 simulator.py {} {} {}".format(policy[0], policy[1], policy[2]))
    data = json.load(open("output.json"))
    X = []
    Y = []
    for elem in data:
        #if elem['time'] >= 10000 and elem['time'] <= 20000:
        X.append(elem['time'])
        Y.append(elem['current energy'])
    plt.title("CPU utilization over time", fontsize = 24)
    plt.plot(X, Y, label = policy)

# ideal result in terms of number of bins used, simply the ideal_bins_number = int(total_util) + 1
    
#os.system("python3 simulator.py {}".format(policy, 'non-adaptive'))
#data = json.load(open("output.json"))
#X = []
#Y = []
#for elem in data:
#    X.append(elem['time'])
#    Y.append(elem['ideal result'])
#
#plt.plot(X, Y, label = 'ideal result')
plt.legend(fontsize = 20)
print("Total time = {}".format(time.time() - timer))
# Out:
# Total time = 204.50273084640503

# %%
import matplotlib.pyplot as plt  
import os
import json
import time

os.system("python3 generator.py 23 poisson")

plt.figure(figsize = (20, 10))

#for day in range(20):
#    if day * 1440 >= 10000 and day * 1440 <= 20000:
#        plt.vlines(x = day * 1440, ymin = 28, ymax = 38, colors= 'purple', ls = '--', lw = 2)

timer = time.time()
policies = [['min-skew', 'no-migration', 'non-adaptive'],
            ['worst-fit', 'no-migration', 'non-adaptive'],
            ['first-fit', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'adaptive'],
            ['best-fit', 'migration-simple', 'non-adaptive'],
            ['min-add-time-bf', 'no-migration', 'non-adaptive'],
            ['min-add-time-bf', 'migration-simple', 'adaptive'],]
for policy in policies:
    os.system("python3 simulator.py {} {} {}".format(policy[0], policy[1], policy[2]))
    data = json.load(open("output.json"))
    X = []
    Y = []
    for elem in data:
        #if elem['time'] >= 10000 and elem['time'] <= 20000:
        X.append(elem['time'])
        Y.append(elem['current energy'])
    plt.title("CPU utilization over time", fontsize = 24)
    plt.plot(X, Y, label = policy)

# ideal result in terms of number of bins used, simply the ideal_bins_number = int(total_util) + 1
    
#os.system("python3 simulator.py {}".format(policy, 'non-adaptive'))
#data = json.load(open("output.json"))
#X = []
#Y = []
#for elem in data:
#    X.append(elem['time'])
#    Y.append(elem['ideal result'])
#
#plt.plot(X, Y, label = 'ideal result')
plt.legend(fontsize = 20)
print("Total time = {}".format(time.time() - timer))
# Out:
# Total time = 709.3370077610016
