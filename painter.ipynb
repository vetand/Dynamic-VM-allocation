# %%
import matplotlib.pyplot as plt  
import os
import json
import time

os.system("python3 generator.py 23 poisson 1")

plt.figure(figsize = (20, 10))

#for day in range(20):
#    if day * 1440 >= 10000 and day * 1440 <= 20000:
#        plt.vlines(x = day * 1440, ymin = 28, ymax = 38, colors= 'purple', ls = '--', lw = 2)

plt.vlines(x = 250000, ymin = 0, ymax = 60, colors= 'purple', ls = '--', lw = 2)
plt.vlines(x = 500000, ymin = 0, ymax = 60, colors= 'purple', ls = '--', lw = 2)

timer = time.time()
policies = [['min-skew', 'no-migration', 'non-adaptive'],
            ['worst-fit', 'no-migration', 'non-adaptive'],
            ['first-fit', 'no-migration', 'non-adaptive'],
            ['first-fit-f-res', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'non-adaptive'],
            ['best-fit-cpu', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'adaptive'],
            ['best-fit', 'migration-simple', 'non-adaptive'],
            ['min-add-time-bf', 'no-migration', 'non-adaptive'],
            ['min-add-time-bf', 'migration-simple', 'adaptive'],]

for policy in policies:
    os.system("python3 simulator.py {} {} {} 250000 500000".format(policy[0], policy[1], policy[2]))
    data = json.load(open("output.json"))
    X = []
    Y = []
    for elem in data:
        #if elem['time'] >= 10000 and elem['time'] <= 20000:
        X.append(elem['time'])
        Y.append(elem['current energy'])
    plt.title("Energy consumption over time", fontsize = 24)
    plt.plot(X, Y, label = policy)

# ideal result in terms of number of bins used, simply the ideal_bins_number = int(total_util) + 1
    
#os.system("python3 simulator.py {}".format(policy, 'non-adaptive'))
#data = json.load(open("output.json"))
#X = []
#Y = []
#for elem in data:
#    X.append(elem['time'])
#    Y.append(elem['ideal result'])
#
#plt.plot(X, Y, label = 'ideal result')
plt.legend(fontsize = 12)
print("Total time = {}".format(time.time() - timer))
# Out:
# Total time = 199.69826221466064

# %%
import matplotlib.pyplot as plt  
import os
import json
import time

os.system("python3 generator.py 23 poisson 2")

plt.figure(figsize = (20, 10))

#for day in range(20):
#    if day * 1440 >= 10000 and day * 1440 <= 20000:
#        plt.vlines(x = day * 1440, ymin = 28, ymax = 38, colors= 'purple', ls = '--', lw = 2)

plt.vlines(x = 300000, ymin = 0, ymax = 40, colors= 'purple', ls = '--', lw = 2)
plt.vlines(x = 600000, ymin = 0, ymax = 40, colors= 'purple', ls = '--', lw = 2)

timer = time.time()
policies = [['min-skew', 'no-migration', 'non-adaptive'],
            ['worst-fit', 'no-migration', 'non-adaptive'],
            ['first-fit', 'no-migration', 'non-adaptive'],
            ['first-fit-f-res', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'non-adaptive'],
            ['best-fit-cpu', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'adaptive'],
            ['best-fit', 'migration-simple', 'non-adaptive'],
            ['min-add-time-bf', 'no-migration', 'non-adaptive'],
            ['min-add-time-bf', 'migration-simple', 'adaptive'],]
for policy in policies:
    os.system("python3 simulator.py {} {} {} 300000 600000".format(policy[0], policy[1], policy[2]))
    data = json.load(open("output.json"))
    X = []
    Y = []
    for elem in data:
        #if elem['time'] >= 10000 and elem['time'] <= 20000:
        X.append(elem['time'])
        Y.append(elem['current energy'])
    plt.title("Energy consumption over time", fontsize = 24)
    plt.plot(X, Y, label = policy)

# ideal result in terms of number of bins used, simply the ideal_bins_number = int(total_util) + 1
    
#os.system("python3 simulator.py {}".format(policy, 'non-adaptive'))
#data = json.load(open("output.json"))
#X = []
#Y = []
#for elem in data:
#    X.append(elem['time'])
#    Y.append(elem['ideal result'])
#
#plt.plot(X, Y, label = 'ideal result')
plt.legend(fontsize = 12)
print("Total time = {}".format(time.time() - timer))
# Out:
# Total time = 121.05111479759216

# %%
import matplotlib.pyplot as plt  
import os
import json
import time

os.system("python3 generator.py 23 poisson 3")

plt.figure(figsize = (20, 10))

#for day in range(20):
#    if day * 1440 >= 10000 and day * 1440 <= 20000:
#        plt.vlines(x = day * 1440, ymin = 28, ymax = 38, colors= 'purple', ls = '--', lw = 2)

plt.vlines(x = 200000, ymin = 0, ymax = 70, colors= 'purple', ls = '--', lw = 2)
plt.vlines(x = 330000, ymin = 0, ymax = 70, colors= 'purple', ls = '--', lw = 2)

timer = time.time()
policies = [['min-skew', 'no-migration', 'non-adaptive'],
            ['worst-fit', 'no-migration', 'non-adaptive'],
            ['first-fit', 'no-migration', 'non-adaptive'],
            ['first-fit-f-res', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'non-adaptive'],
            ['best-fit-cpu', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'adaptive'],
            ['best-fit', 'migration-simple', 'non-adaptive'],
            ['min-add-time-bf', 'no-migration', 'non-adaptive'],
            ['min-add-time-bf', 'migration-simple', 'adaptive'],]
for policy in policies:
    os.system("python3 simulator.py {} {} {} 200000 330000".format(policy[0], policy[1], policy[2]))
    data = json.load(open("output.json"))
    X = []
    Y = []
    for elem in data:
        #if elem['time'] >= 10000 and elem['time'] <= 20000:
        X.append(elem['time'])
        Y.append(elem['current energy'])
    plt.title("Energy consumption over time", fontsize = 24)
    plt.plot(X, Y, label = policy)

# ideal result in terms of number of bins used, simply the ideal_bins_number = int(total_util) + 1
    
#os.system("python3 simulator.py {}".format(policy, 'non-adaptive'))
#data = json.load(open("output.json"))
#X = []
#Y = []
#for elem in data:
#    X.append(elem['time'])
#    Y.append(elem['ideal result'])
#
#plt.plot(X, Y, label = 'ideal result')
plt.legend(fontsize = 12)
print("Total time = {}".format(time.time() - timer))
# Out:
# Total time = 143.62808680534363

# %%
import matplotlib.pyplot as plt  
import os
import json
import time

os.system("python3 generator.py 23 poisson 4")

plt.figure(figsize = (20, 10))

#for day in range(20):
#    if day * 1440 >= 10000 and day * 1440 <= 20000:
#        plt.vlines(x = day * 1440, ymin = 28, ymax = 38, colors= 'purple', ls = '--', lw = 2)

plt.vlines(x = 200000, ymin = 0, ymax = 70, colors= 'purple', ls = '--', lw = 2)
plt.vlines(x = 400000, ymin = 0, ymax = 70, colors= 'purple', ls = '--', lw = 2)

timer = time.time()
policies = [['min-skew', 'no-migration', 'non-adaptive'],
            ['worst-fit', 'no-migration', 'non-adaptive'],
            ['first-fit', 'no-migration', 'non-adaptive'],
            ['first-fit-f-res', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'non-adaptive'],
            ['best-fit-cpu', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'adaptive'],
            ['best-fit', 'migration-simple', 'non-adaptive'],
            ['min-add-time-bf', 'no-migration', 'non-adaptive'],
            ['min-add-time-bf', 'migration-simple', 'adaptive'],]
for policy in policies:
    os.system("python3 simulator.py {} {} {} 200000 400000".format(policy[0], policy[1], policy[2]))
    data = json.load(open("output.json"))
    X = []
    Y = []
    for elem in data:
        #if elem['time'] >= 10000 and elem['time'] <= 20000:
        X.append(elem['time'])
        Y.append(elem['current energy'])
    plt.title("Energy consumption over time", fontsize = 24)
    plt.plot(X, Y, label = policy)

# ideal result in terms of number of bins used, simply the ideal_bins_number = int(total_util) + 1
    
#os.system("python3 simulator.py {}".format(policy, 'non-adaptive'))
#data = json.load(open("output.json"))
#X = []
#Y = []
#for elem in data:
#    X.append(elem['time'])
#    Y.append(elem['ideal result'])
#
#plt.plot(X, Y, label = 'ideal result')
plt.legend(fontsize = 12)
print("Total time = {}".format(time.time() - timer))
# Out:
# Total time = 149.36858415603638

# %%
import matplotlib.pyplot as plt  
import os
import json
import time

os.system("python3 generator.py 23 poisson 5")

plt.figure(figsize = (20, 10))

#for day in range(20):
#    if day * 1440 >= 10000 and day * 1440 <= 20000:
#        plt.vlines(x = day * 1440, ymin = 28, ymax = 38, colors= 'purple', ls = '--', lw = 2)

plt.vlines(x = 200000, ymin = 0, ymax = 65, colors= 'purple', ls = '--', lw = 2)
plt.vlines(x = 400000, ymin = 0, ymax = 65, colors= 'purple', ls = '--', lw = 2)

timer = time.time()
policies = [['min-skew', 'no-migration', 'non-adaptive'],
            ['worst-fit', 'no-migration', 'non-adaptive'],
            ['first-fit', 'no-migration', 'non-adaptive'],
            ['first-fit-f-res', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'non-adaptive'],
            ['best-fit-cpu', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'adaptive'],
            ['best-fit', 'migration-simple', 'non-adaptive'],
            ['min-add-time-bf', 'no-migration', 'non-adaptive'],
            ['min-add-time-bf', 'migration-simple', 'adaptive'],]
for policy in policies:
    os.system("python3 simulator.py {} {} {} 200000 400000".format(policy[0], policy[1], policy[2]))
    data = json.load(open("output.json"))
    X = []
    Y = []
    for elem in data:
        #if elem['time'] >= 10000 and elem['time'] <= 20000:
        X.append(elem['time'])
        Y.append(elem['current energy'])
    plt.title("Energy consumption over time", fontsize = 24)
    plt.plot(X, Y, label = policy)

# ideal result in terms of number of bins used, simply the ideal_bins_number = int(total_util) + 1
    
#os.system("python3 simulator.py {}".format(policy, 'non-adaptive'))
#data = json.load(open("output.json"))
#X = []
#Y = []
#for elem in data:
#    X.append(elem['time'])
#    Y.append(elem['ideal result'])
#
#plt.plot(X, Y, label = 'ideal result')
plt.legend(fontsize = 12)
print("Total time = {}".format(time.time() - timer))
# Out:
# Total time = 145.45127511024475

# %%
import matplotlib.pyplot as plt  
import os
import json
import time

os.system("python3 generator.py 23 poisson 6")

plt.figure(figsize = (20, 10))

#for day in range(20):
#    if day * 1440 >= 10000 and day * 1440 <= 20000:
#        plt.vlines(x = day * 1440, ymin = 28, ymax = 38, colors= 'purple', ls = '--', lw = 2)

plt.vlines(x = 7500, ymin = 0, ymax = 55, colors= 'purple', ls = '--', lw = 2)
plt.vlines(x = 17500, ymin = 0, ymax = 55, colors= 'purple', ls = '--', lw = 2)

timer = time.time()
policies = [['min-skew', 'no-migration', 'non-adaptive'],
            ['worst-fit', 'no-migration', 'non-adaptive'],
            ['first-fit', 'no-migration', 'non-adaptive'],
            ['first-fit-f-res', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'non-adaptive'],
            ['best-fit-cpu', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'adaptive'],
            ['best-fit', 'migration-simple', 'non-adaptive'],
            ['min-add-time-bf', 'no-migration', 'non-adaptive'],
            ['min-add-time-bf', 'migration-simple', 'adaptive'],]
for policy in policies:
    os.system("python3 simulator.py {} {} {} 7500 17500".format(policy[0], policy[1], policy[2]))
    data = json.load(open("output.json"))
    X = []
    Y = []
    for elem in data:
        #if elem['time'] >= 10000 and elem['time'] <= 20000:
        X.append(elem['time'])
        Y.append(elem['current energy'])
    plt.title("Energy consumption over time", fontsize = 24)
    plt.plot(X, Y, label = policy)

# ideal result in terms of number of bins used, simply the ideal_bins_number = int(total_util) + 1
    
#os.system("python3 simulator.py {}".format(policy, 'non-adaptive'))
#data = json.load(open("output.json"))
#X = []
#Y = []
#for elem in data:
#    X.append(elem['time'])
#    Y.append(elem['ideal result'])
#
#plt.plot(X, Y, label = 'ideal result')
plt.legend(fontsize = 12)
print("Total time = {}".format(time.time() - timer))
# Out:
# Total time = 403.413845539093

# %%
import matplotlib.pyplot as plt  
import os
import json
import time

os.system("python3 generator.py 23 poisson 7")

plt.figure(figsize = (20, 10))

#for day in range(20):
#    if day * 1440 >= 10000 and day * 1440 <= 20000:
#        plt.vlines(x = day * 1440, ymin = 28, ymax = 38, colors= 'purple', ls = '--', lw = 2)

timer = time.time()
policies = [['min-skew', 'no-migration', 'non-adaptive'],
            ['worst-fit', 'no-migration', 'non-adaptive'],
            ['first-fit', 'no-migration', 'non-adaptive'],
            ['first-fit-f-res', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'non-adaptive'],
            ['best-fit-cpu', 'no-migration', 'non-adaptive'],
            ['best-fit', 'no-migration', 'adaptive'],
            ['best-fit', 'migration-simple', 'non-adaptive'],
            ['min-add-time-bf', 'no-migration', 'non-adaptive'],
            ['min-add-time-bf', 'migration-simple', 'adaptive'],]
for policy in policies:
    os.system("python3 simulator.py {} {} {} 0 100000000".format(policy[0], policy[1], policy[2]))
    data = json.load(open("output.json"))
    X = []
    Y = []
    for elem in data:
        #if elem['time'] >= 10000 and elem['time'] <= 20000:
        X.append(elem['time'])
        Y.append(elem['current energy'])
    plt.title("Energy consumption over time", fontsize = 24)
    plt.plot(X, Y, label = policy)

# ideal result in terms of number of bins used, simply the ideal_bins_number = int(total_util) + 1
    
#os.system("python3 simulator.py {}".format(policy, 'non-adaptive'))
#data = json.load(open("output.json"))
#X = []
#Y = []
#for elem in data:
#    X.append(elem['time'])
#    Y.append(elem['ideal result'])
#
#plt.plot(X, Y, label = 'ideal result')
plt.legend(fontsize = 12)
print("Total time = {}".format(time.time() - timer))
# Out:
# Total time = 4964.1884779930115
# /home/vetand/.local/lib/python3.8/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
